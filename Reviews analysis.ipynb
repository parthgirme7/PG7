# %%
#Hey this is eugene, just testing to see if it works

import pandas as pd
import numpy as np

df = pd.read_csv('OnlineNewsPopularity.csv')
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs   ...     \
# ...

# %%
## Dropping URL variable & using describe###
df.drop('url', axis = 1, inplace = True)
df = df.astype(int)
df.describe().T
# Out:
#                                   count           mean            std  min  \
#  timedelta                      39644.0     354.530471     214.163767  8.0
#  n_tokens_title                 39644.0      10.398749       2.114037  2.0
#  n_tokens_content               39644.0     546.514731     471.107508  0.0
#  n_unique_tokens                39644.0       0.017682       3.520702  0.0
#  n_non_stop_words               39644.0       0.026284       5.233340  0.0
#  n_non_stop_unique_tokens       39644.0       0.016396       3.264560  0.0
#  num_hrefs                      39644.0      10.883690      11.332017  0.0
#  num_self_hrefs                 39644.0       3.293638       3.855141  0.0
#  num_imgs                       39644.0       4.544143       8.309434  0.0
#  num_videos                     39644.0       1.249874       4.107855  0.0
#  average_token_length           39644.0       4.001110       0.778594  0.0
# ...

# %%
## checking number of unique values for each var ###
for i in df:
    print(i,(df[i].nunique()))
# Out:
#  timedelta 724
#  n_tokens_title 20
#  n_tokens_content 2406
#  n_unique_tokens 2
#  n_non_stop_words 2
#  n_non_stop_unique_tokens 2
#  num_hrefs 133
#  num_self_hrefs 59
#  num_imgs 91
#  num_videos 53
#  average_token_length 7
#  num_keywords 10
#  data_channel_is_lifestyle 2
#  data_channel_is_entertainment 2
#  data_channel_is_bus 2
#  data_channel_is_socmed 2
#  data_channel_is_tech 2
#  data_channel_is_world 2
#  kw_min_min 26
#  kw_max_min 1076
#  kw_avg_min 1735
#  kw_min_max 1021
#  kw_max_max 35
#  kw_avg_max 30656
#  kw_min_avg 3139
#  kw_max_avg 7293
#  kw_avg_avg 5350
#  self_reference_min_shares 1254
#  self_reference_max_shares 1137
#  self_reference_avg_sharess 5946
#  weekday_is_monday 2
#  weekday_is_tuesday 2
#  weekday_is_wednesday 2
#  weekday_is_thursday 2
#  weekday_is_friday 2
#  weekday_is_saturday 2
#  weekday_is_sunday 2
#  is_weekend 2
#  LDA_00 1
#  LDA_01 1
#  LDA_02 1
#  LDA_03 1
#  LDA_04 1
#  global_subjectivity 2
#  global_sentiment_polarity 1
# ...

# %%
## making token titles object for prediction ####
df[' n_tokens_title'] = df[' n_tokens_title'].astype(object)

# %%
## plots on plots ####

import matplotlib.pyplot as plt
import seaborn as sns

#df["n_tokens_title"] = df["n_tokens_title"].astype(object)
sns.barplot(x = " n_tokens_title", y = " shares", data = df)
plt.show()
# Out:
# C:\Users\ParthGirme7\Anaconda3\anaconda3one\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x = " title_sentiment_polarity", y = " shares", data = df)
plt.show()
# Out:
# C:\Users\ParthGirme7\Anaconda3\anaconda3one\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import seaborn as sns
a = df[(df[' shares'] <= 25000) & (df[" n_tokens_content"] <= 4000)]
sns.regplot(x = " n_tokens_content", y = ' shares', data = a, scatter_kws={'alpha':0.2})
plt.show()
# Out:
# C:\Users\ParthGirme7\Anaconda3\anaconda3one\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import seaborn as sns
a = df.loc[(df[' shares'] <= 6500) & (df[" n_tokens_content"] <= 4000), [" n_tokens_title", ' shares']]
sns.boxplot(x = " n_tokens_title", y = ' shares', data = a)
plt.show()

# %%
a = df.loc[(df[' n_tokens_content'] <= 2500)]
sns.boxplot(x = " n_tokens_title", y = " n_tokens_content", data = a)
